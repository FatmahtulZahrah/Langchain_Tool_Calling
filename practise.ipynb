# %% [markdown]
# <a href="https://colab.research.google.com/github/FatmahtulZahrah/Langchain_Tool_Calling/blob/main/practise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bicycles=["yamaha","honda","hero honda","suzuki"]
print(bicycles)
# Out:
# ['yamaha', 'honda', 'hero honda', 'suzuki']

# %%
print(bicycles[1])
print(bicycles[3])
print("bike name:",bicycles[2].title())
# Out:
# honda
# suzuki
# bike name: Hero Honda

# %%
print(bicycles[0])
# Out:
# yamaha

# %% [markdown]
# accessing last element

# %%
print(bicycles[-1])
print(bicycles[-2])
# Out:
# suzuki
# hero honda

# %%
message=f"i got my first bike {bicycles[0].title()}"
print(message)
# Out:
# i got my first bike Yamaha

# %%
message_2=f"i got my 2nd bike {bicycles[1].title()}"
print(message_2)
# Out:
# i got my 2nd bike Honda

# %%
bicycles.append("new honda")
print(bicycles)
# Out:
# ['yamaha', 'honda', 'hero honda', 'suzuki', 'new honda']

# %%
bicycles.pop()
print(bicycles)
# Out:
# ['yamaha', 'honda', 'hero honda']

# %%
bicycles[1]=("bmx")
print(bicycles)
bicycles.insert(2,"hero honda")
print(bicycles)
# Out:
# ['ducati', 'bmx', 'hero hona', 'hero honda', 'hero honda', 'hero honda*3', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda']
# ['ducati', 'bmx', 'hero honda', 'hero hona', 'hero honda', 'hero honda', 'hero honda*3', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda', 'hero honda']

# %%
bicycles.remove("hero honda")
print(bicycles)
# Out:
# ['yamaha', 'honda']

# %%
print(bicycles[2])
# Out:
# hero hona

# %%
# Very simple to-do list without using if/else

todo_list = []

# Add 3 tasks (you can change this number)
task1 = input("Enter task 1: ")
todo_list.append(task1)

task2 = input("Enter task 2: ")
todo_list.append(task2)

task3 = input("Enter task 3: ")
todo_list.append(task3)

# Show the tasks
print("\nYour To-Do List:")
print(todo_list)
# Out:
# Enter task 1: 12
# Enter task 2: 24
# Enter task 3: 12
#
# Your To-Do List:
# ['12', '24', '12']

# %%
fruits=["banana","mango","cherry","melon","watermelon","apple"]
if "apple" in fruits and "banana" in fruits:
  print("both are in fruits")
else:
  print("apple is not in fruits")
# Out:
# both are in fruits

# %%
fruits=[]
fruits_1=input("enter your fruit:")
fruits_2=input("enter your fruit:")
fruits_3=input("enter your fruit:")
fruits.append(fruits_1)
fruits.append(fruits_2)
fruits.append(fruits_3)
if "apple" in fruits and "banana" in fruits:
  print("you have entered both fruits")
elif "apple" in fruits:
  print("you have only entered apple")
elif "banana" in fruits:
  print("you have entered only banana")
else:
     print("apple and bana not fruits")
# Out:
# enter your fruit:nike
# enter your fruit:mike
# enter your fruit:like
# apple and bana not fruits
